# %% [markdown]
# # Looking at near-surface reflector structure across seasons and stations

# %%
# Load libraries
import sys
import sys
sys.path.append("../../../xapres_package/")
import ApRESDefs
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker 
import pickle

import xarray as xr
import importlib
import pandas as pd
import math
from datetime import datetime, timedelta, date
from scipy.stats import linregress
from helpers import *

importlib.reload(ApRESDefs)
xa = ApRESDefs.xapres(loglevel='debug')
# Out:
# DEBUG    17:35:48 	 ApRESDefs.py @function _setup_logging line 615 - Stream logging level set to DEBUG
# DEBUG    17:35:48 	 ApRESDefs.py @function _setup_logging line 616 - Add console handler to logger
# DEBUG    17:35:48 	 ApRESDefs.py @function _setup_logging line 629 - File logging level set to DEBUG

# %% [markdown]
# ## A11

# %%
with open('../chirp_processing/A11_22S.pickle', 'rb') as handle:
    s22 = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(s22).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(s22).idxmax(dim='profile_range').plot()

# %%
with open('../chirp_processing/A11_22W.pickle', 'rb') as handle:
    winter = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(winter).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(winter).idxmax(dim='profile_range').plot()

# %%
a11 = xr.concat([abs(s22).idxmax(dim='profile_range'),abs(winter).idxmax(dim='profile_range')],dim='time')

# %%
fig, ax = plt.subplots(figsize=(15,5))
a11.plot(linestyle='none',marker='.')

# %% [markdown]
# # A13

# %%
with open('../chirp_processing/A13_22S.pickle', 'rb') as handle:
    s22 = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(s22).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(s22).idxmax(dim='profile_range').plot()

# %%
with open('../chirp_processing/A13_22W.pickle', 'rb') as handle:
    winter = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(winter).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(winter).idxmax(dim='profile_range').plot()

# %%
with open('../chirp_processing/A13_23S.pickle', 'rb') as handle:
    s23 = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(s23).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(s23).idxmax(dim='profile_range').plot()

# %%
a13 = xr.concat([abs(s22).idxmax(dim='profile_range'),abs(winter).idxmax(dim='profile_range'),abs(s23).idxmax(dim='profile_range')],dim='time')

# %%
fig, ax = plt.subplots(figsize=(15,5))
a11.plot(linestyle='none',marker='.',label = 'A11')
a13.plot(linestyle='none',marker='.',label = 'A13')

# %% [markdown]
# # A14

# %%
with open('../chirp_processing/A14_22S.pickle', 'rb') as handle:
    s22 = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(s22).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(s22).idxmax(dim='profile_range').plot()

# %%
with open('../chirp_processing/A14_22W.pickle', 'rb') as handle:
    winter = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(winter).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(winter).idxmax(dim='profile_range').plot()

# %%
with open('../chirp_processing/A14_23S.pickle', 'rb') as handle:
    s23 = pickle.load(handle)

# %%
fig, ax = plt.subplots(figsize=(15,5))
xa.dB(s23).plot(x='time')
ax.invert_yaxis()
#import datetime
#xlim=[datetime.date(2022, 12, 1), datetime.date(2023, 4, 1)]
plt.ylim([200,0])
# Out:
# (200.0, 0.0)

# %%
abs(s23).idxmax(dim='profile_range').plot()

# %%
a14 = xr.concat([abs(s22).idxmax(dim='profile_range'),abs(winter).idxmax(dim='profile_range'),abs(s23).idxmax(dim='profile_range')],dim='time')

# %%
fig, ax = plt.subplots(figsize=(15,5))
a11.plot(linestyle='none',marker='.',label = 'A11')
a13.plot(linestyle='none',marker='.',label = 'A13')
a14.plot(linestyle='none',marker='.',label = 'A14')
plt.legend()
plt.ylim([0,40])
plt.ylabel('Depth of strongest reflector [m]')
# Out:
# Text(0, 0.5, 'Depth of strongest reflector [m]')

# %%
a13.median()
# Out:
# <xarray.DataArray 'profile_range' ()> Size: 8B
# array(6.30931767)
