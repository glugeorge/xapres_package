# %% [markdown]
# # Quicklook station by station
#
# This notebook serves as a template in a series of tests to determine if we can determine valid strain rates from our winter ApRES measurements. It condenses the calculations into an individual cell which can be duplicated for every change in parameters. To avoid creating too long of a notebook which requires a lot of scrolling, duplicate this template for each parameter to test, and for each station.

# %%
from to_import import *

# %%
# Set up dask cluster to help with computation
from dask.distributed import Client

client = Client("tcp://127.0.0.1:36617")
client
# Out:
# <Client: 'tcp://127.0.0.1:36617' processes=4 threads=16, memory=125.81 GiB>

# %% [markdown]
# The next two blocks is the script that needs to be copied and altered for each individual test. It will output a profile plot, displacement plot (individual lines), and a strain rate plot. The first block is where all the alterations are done, the second is the one that will output everything. To condense the code, the functions are all located in the `to_import.py` script, and are called in the second block

# %%
# To alter
# Stacking of profiles
stacking = '1H'

# Window for vertical displacement
vd_window = 20

# Resolution of displacement resample
vd_sum = '1D'

# Factor for vertical coarsening of displacements
vd_coarse = 1
generate_plots('A101',stacking,vd_window,vd_sum,vd_coarse)
# Out:
# DEBUG    22:10:29 	 ApRESDefs.py @function _setup_logging line 539 - Stream logging level set to DEBUG
# DEBUG    22:10:29 	 ApRESDefs.py @function _setup_logging line 540 - Add console handler to logger
# DEBUG    22:10:29 	 ApRESDefs.py @function _setup_logging line 553 - File logging level set to DEBUG
# 22:10:31: Data loaded
# 22:11:12: Profiles calculated
# INFO     22:11:13 	 ApRESDefs.py @function generate_range_diff line 594 - Time between bursts : [3600. 3600. 3600. ... 3600. 3600. 3600.]s
# 22:11:23: Displacements calculated
# 22:11:23: Strain rate calculated

# %%
# To alter
# Stacking of profiles
stacking = '1H'

# Window for vertical displacement
vd_window = 30

# Resolution of displacement resample
vd_sum = '2D'

# Factor for vertical coarsening of displacements
vd_coarse = 1
generate_plots('A103',stacking,vd_window,vd_sum,vd_coarse)
# Out:
# DEBUG    22:11:57 	 ApRESDefs.py @function _setup_logging line 539 - Stream logging level set to DEBUG
# DEBUG    22:11:57 	 ApRESDefs.py @function _setup_logging line 540 - Add console handler to logger
# DEBUG    22:11:57 	 ApRESDefs.py @function _setup_logging line 553 - File logging level set to DEBUG
# 22:11:57: Data loaded
# 22:12:34: Profiles calculated
# INFO     22:12:35 	 ApRESDefs.py @function generate_range_diff line 594 - Time between bursts : [3600. 3600. 3600. ... 3600. 3600. 3600.]s
# 22:12:42: Displacements calculated
# 22:12:42: Strain rate calculated

# %%
generate_plots('A104',stacking,vd_window,vd_sum,vd_coarse)
# Out:
# DEBUG    22:13:15 	 ApRESDefs.py @function _setup_logging line 539 - Stream logging level set to DEBUG
# DEBUG    22:13:15 	 ApRESDefs.py @function _setup_logging line 540 - Add console handler to logger
# DEBUG    22:13:15 	 ApRESDefs.py @function _setup_logging line 553 - File logging level set to DEBUG
# 22:13:15: Data loaded
# 22:13:33: Profiles calculated
# INFO     22:13:35 	 ApRESDefs.py @function generate_range_diff line 594 - Time between bursts : [3600. 3600. 3600. ... 3600. 3600. 3600.]s
# /home/jovyan/xapres_package/notebooks/test_notes/strain_rate_notes/winter_strain_rate_tests/../../../../xapres_package/ApRESDefs.py:579: RuntimeWarning: invalid value encountered in divide
#   c = top/bottom
# 22:13:39: Displacements calculated
# 22:13:40: Strain rate calculated
# /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1103: RuntimeWarning: All-NaN axis encountered
#   minx = np.nanmin(masked_verts[..., 0])
# ...
