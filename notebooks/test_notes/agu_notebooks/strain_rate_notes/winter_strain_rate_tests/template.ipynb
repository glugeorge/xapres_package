# %% [markdown]
# # Template for winter strain rate calculations
#
# This notebook serves as a template in a series of tests to determine if we can determine valid strain rates from our winter ApRES measurements. It condenses the calculations into an individual cell which can be duplicated for every change in parameters. To avoid creating too long of a notebook which requires a lot of scrolling, duplicate this template for each parameter to test, and for each station.

# %%
from to_import import *

# %%
# Set up dask cluster to help with computation
from dask.distributed import Client

client = Client("tcp://127.0.0.1:38865")
client
# Out:
# <Client: 'tcp://127.0.0.1:38865' processes=1 threads=4, memory=31.45 GiB>

# %% [markdown]
# The next two blocks is the script that needs to be copied and altered for each individual test. It will output a profile plot, displacement plot (individual lines), and a strain rate plot. The first block is where all the alterations are done, the second is the one that will output everything. To condense the code, the functions are all located in the `to_import.py` script, and are called in the second block

# %%
# To alter

# Station
station = 'A103'

# Stacking of profiles
stacking = '1H'

# Window for vertical displacement
vd_window = 20

# Resolution of displacement resample
vd_sum = '1D'

# Factor for vertical coarsening of displacements
vd_coarse = 1

# %%
xa = ApRESDefs.xapres(loglevel='debug')
ds_winter = reload_winter('A103')
# Out:
# DEBUG    18:23:47 	 ApRESDefs.py @function _setup_logging line 539 - Stream logging level set to DEBUG
# DEBUG    18:23:47 	 ApRESDefs.py @function _setup_logging line 540 - Add console handler to logger
# DEBUG    18:23:47 	 ApRESDefs.py @function _setup_logging line 553 - File logging level set to DEBUG

# %%
xa.dB(ds_winter.profile_stacked.isel(profile_range = 20,attenuator_setting_pair=1)).plot()

# %%
generate_plots(station,stacking,vd_window,vd_sum,vd_coarse)
# Out:
# DEBUG    16:34:46 	 ApRESDefs.py @function _setup_logging line 539 - Stream logging level set to DEBUG
# DEBUG    16:34:46 	 ApRESDefs.py @function _setup_logging line 540 - Add console handler to logger
# DEBUG    16:34:46 	 ApRESDefs.py @function _setup_logging line 553 - File logging level set to DEBUG
# 16:34:49: Data loaded
# 16:35:19: Profiles calculated
# INFO     16:35:21 	 ApRESDefs.py @function generate_range_diff line 594 - Time between bursts : [3600. 3600. 3600. ... 3600. 3600. 3600.]s
# 16:35:30: Displacements calculated
# 16:35:31: Strain rate calculated

# %%
generate_plots(station,stacking,vd_window,vd_sum,5)
# Out:
# DEBUG    16:36:04 	 ApRESDefs.py @function _setup_logging line 539 - Stream logging level set to DEBUG
# DEBUG    16:36:04 	 ApRESDefs.py @function _setup_logging line 540 - Add console handler to logger
# DEBUG    16:36:04 	 ApRESDefs.py @function _setup_logging line 553 - File logging level set to DEBUG
# 16:36:05: Data loaded
# 16:36:25: Profiles calculated
# INFO     16:36:27 	 ApRESDefs.py @function generate_range_diff line 594 - Time between bursts : [3600. 3600. 3600. ... 3600. 3600. 3600.]s
# 16:36:37: Displacements calculated
# 16:36:38: Strain rate calculated
